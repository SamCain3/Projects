# %%
# Import required libraries and dependencies

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense

# %%
train_data = pd.read_csv('Resources/GME_data.csv')
training_set = train_data.iloc[:, 1:2].values

# %%
train_data
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2020-12-21   3.952500   4.087500   3.820000   3.882500   3.882500
# 1    2020-12-22   4.055000   5.010000   4.037500   4.865000   4.865000
# 2    2020-12-23   5.042500   5.587500   4.782500   5.142500   5.142500
# 3    2020-12-24   5.252500   5.370000   4.987500   5.037500   5.037500
# 4    2020-12-28   5.327500   5.492500   5.087500   5.247500   5.247500
# ..          ...        ...        ...        ...        ...        ...
# 414  2022-08-15  39.750000  40.389999  38.810001  39.680000  39.680000
# 415  2022-08-16  39.169998  45.529999  38.599998  42.189999  42.189999
# 416  2022-08-17  42.180000  44.360001  40.410000  40.520000  40.520000
# 417  2022-08-18  39.270000  40.070000  37.340000  37.930000  37.930000
# 418  2022-08-19  35.180000  37.189999  34.669998  36.490002  36.490002
#
#         Volume
# 0     39504400
# 1    122610800
# 2    103321200
# 3     25048800
# 4     35863600
# ..         ...
# 414    5243100
# 415   23602800
# 416    9766400
# 417    8145400
# 418    9551900
#
# [419 rows x 7 columns]

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []

for i in range(20, 419):
    X_train.append(training_set_scaled[i-20:i, 0])
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 5s 25ms/step - loss: 0.0602
# Epoch 2/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0206
# Epoch 3/100
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0172
# Epoch 4/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0166
# Epoch 5/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0164
# Epoch 6/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0168
# Epoch 7/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0165
# Epoch 8/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0164
# Epoch 9/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0163
# Epoch 10/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0162
# Epoch 11/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0152
# Epoch 12/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0155
# Epoch 13/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0151
# Epoch 14/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0147
# Epoch 15/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0143
# Epoch 16/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0147
# Epoch 17/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0144
# Epoch 18/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0137
# Epoch 19/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0141
# Epoch 20/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0133
# Epoch 21/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0137
# Epoch 22/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0130
# Epoch 23/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0138
# Epoch 24/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0131
# Epoch 25/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0125
# Epoch 26/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0132
# Epoch 27/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0129
# Epoch 28/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0126
# Epoch 29/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0120
# Epoch 30/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0114
# Epoch 31/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0105
# Epoch 32/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0111
# Epoch 33/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0109
# Epoch 34/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0106
# Epoch 35/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0096
# Epoch 36/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0096
# Epoch 37/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0093
# Epoch 38/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0094
# Epoch 39/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0091
# Epoch 40/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0092
# Epoch 41/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0083
# Epoch 42/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0081
# Epoch 43/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0093
# Epoch 44/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0090
# Epoch 45/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0088
# Epoch 46/100
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0073
# Epoch 47/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0074
# Epoch 48/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0074
# Epoch 49/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0070
# Epoch 50/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0070
# Epoch 51/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0067
# Epoch 52/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0072
# Epoch 53/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0066
# Epoch 54/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0061
# Epoch 55/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0059
# Epoch 56/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0064
# Epoch 57/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0058
# Epoch 58/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0057
# Epoch 59/100
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0060
# Epoch 60/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0060
# Epoch 61/100
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0060
# Epoch 62/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0057
# Epoch 63/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0053
# Epoch 64/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0059
# Epoch 65/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0051
# Epoch 66/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0053
# Epoch 67/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0060
# Epoch 68/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0056
# Epoch 69/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0052
# Epoch 70/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0049
# Epoch 71/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0049
# Epoch 72/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0047
# Epoch 73/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0047
# Epoch 74/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0045
# Epoch 75/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0050
# Epoch 76/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0048
# Epoch 77/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0050
# Epoch 78/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0051
# Epoch 79/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0053
# Epoch 80/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0054
# Epoch 81/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0054
# Epoch 82/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0050
# Epoch 83/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0048
# Epoch 84/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0047
# Epoch 85/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0044
# Epoch 86/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0050
# Epoch 87/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0042
# Epoch 88/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0043
# Epoch 89/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0044
# Epoch 90/100
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0048
# Epoch 91/100
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0052
# Epoch 92/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0045
# Epoch 93/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0046
# Epoch 94/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0051
# Epoch 95/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0043
# Epoch 96/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0043
# Epoch 97/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0044
# Epoch 98/100
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0040
# Epoch 99/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0045
# Epoch 100/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0043

# %%
dataset_test = pd.read_csv('Resources/GME_data.csv')
real_stock_price = dataset_test.iloc[:, 1:2].values

# %%
dataset_total = pd.concat((train_data['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 20:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(20, 440):
    X_test.append(inputs[i-20:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_price = model.predict(X_test)
predicted_price = sc.inverse_transform(predicted_price)
# Out:
# 14/14 [==============================] - 0s 6ms/step

# %%
plt.plot(real_stock_price, color = 'red', label = 'GME Stock Price')
plt.plot(predicted_price, color = 'blue', label = 'Predicted GME Stock Price')
plt.title('GME Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('GME Stock Price')
plt.legend()
plt.show()
